# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,classification_report
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('car.csv')

# %%
df
# Out:
#      buying_price maintenance_cost number_of_doors number_of_persons lug_boot  \
# 0           vhigh            vhigh               2                 4      med
# 1           vhigh            vhigh               2                 2    small
# 2           vhigh            vhigh               2                 2      med
# 3           vhigh            vhigh               2                 2      med
# 4           vhigh            vhigh               2                 2      med
# ...           ...              ...             ...               ...      ...
# 1722          low              low           5more              more      med
# 1723          low              low           5more              more      med
# 1724          low              low           5more              more      big
# 1725          low              low           5more              more      big
# 1726          low              low           5more              more      big
#
#      safety decision
# 0      high    unacc
# 1      high    unacc
# 2       low    unacc
# 3       med    unacc
# 4      high    unacc
# ...     ...      ...
# 1722    med     good
# 1723   high    vgood
# 1724    low    unacc
# 1725    med     good
# 1726   high    vgood
#
# [1727 rows x 7 columns]

# %%
col_names = ['buying_price','maintenance_cost','lug_boot','safety','decision']
for col in col_names:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])

# %%
df
# Out:
#       buying_price  maintenance_cost number_of_doors number_of_persons  \
# 0                3                 3               2                 4
# 1                3                 3               2                 2
# 2                3                 3               2                 2
# 3                3                 3               2                 2
# 4                3                 3               2                 2
# ...            ...               ...             ...               ...
# 1722             1                 1           5more              more
# 1723             1                 1           5more              more
# 1724             1                 1           5more              more
# 1725             1                 1           5more              more
# 1726             1                 1           5more              more
#
#       lug_boot  safety  decision
# 0            1       0         2
# 1            2       0         2
# 2            1       1         2
# 3            1       2         2
# 4            1       0         2
# ...        ...     ...       ...
# 1722         1       2         1
# 1723         1       0         3
# 1724         0       1         2
# 1725         0       2         1
# 1726         0       0         3
#
# [1727 rows x 7 columns]

# %%
df = df[df['number_of_doors'] != '5more']

# %%
df
# Out:
#       buying_price  maintenance_cost number_of_doors number_of_persons  \
# 0                3                 3               2                 4
# 1                3                 3               2                 2
# 2                3                 3               2                 2
# 3                3                 3               2                 2
# 4                3                 3               2                 2
# ...            ...               ...             ...               ...
# 1695             1                 1               4              more
# 1696             1                 1               4              more
# 1697             1                 1               4              more
# 1698             1                 1               4              more
# 1699             1                 1               4              more
#
#       lug_boot  safety  decision
# 0            1       0         2
# 1            2       0         2
# 2            1       1         2
# 3            1       2         2
# 4            1       0         2
# ...        ...     ...       ...
# 1695         1       2         1
# 1696         1       0         3
# 1697         0       1         2
# 1698         0       2         1
# 1699         0       0         3
#
# [1295 rows x 7 columns]

# %%
df = df[df['number_of_persons'] != 'more']

# %%
df
# Out:
#       buying_price  maintenance_cost number_of_doors number_of_persons  \
# 0                3                 3               2                 4
# 1                3                 3               2                 2
# 2                3                 3               2                 2
# 3                3                 3               2                 2
# 4                3                 3               2                 2
# ...            ...               ...             ...               ...
# 1686             1                 1               4                 4
# 1687             1                 1               4                 4
# 1688             1                 1               4                 4
# 1689             1                 1               4                 4
# 1690             1                 1               4                 4
#
#       lug_boot  safety  decision
# 0            1       0         2
# 1            2       0         2
# 2            1       1         2
# 3            1       2         2
# 4            1       0         2
# ...        ...     ...       ...
# 1686         1       2         1
# 1687         1       0         3
# 1688         0       1         2
# 1689         0       2         1
# 1690         0       0         3
#
# [863 rows x 7 columns]

# %%
x = df.drop('safety',axis=1)
y=df['safety']

# %%
x
# Out:
#       buying_price  maintenance_cost number_of_doors number_of_persons  \
# 0                3                 3               2                 4
# 1                3                 3               2                 2
# 2                3                 3               2                 2
# 3                3                 3               2                 2
# 4                3                 3               2                 2
# ...            ...               ...             ...               ...
# 1686             1                 1               4                 4
# 1687             1                 1               4                 4
# 1688             1                 1               4                 4
# 1689             1                 1               4                 4
# 1690             1                 1               4                 4
#
#       lug_boot  decision
# 0            1         2
# 1            2         2
# 2            1         2
# 3            1         2
# 4            1         2
# ...        ...       ...
# 1686         1         1
# 1687         1         3
# 1688         0         2
# 1689         0         1
# 1690         0         3
#
# [863 rows x 6 columns]

# %%
y
# Out:
# 0       0
# 1       0
# 2       1
# 3       2
# 4       0
#        ..
# 1686    2
# 1687    0
# 1688    1
# 1689    2
# 1690    0
# Name: safety, Length: 863, dtype: int32

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3)

# %%
rf = RandomForestClassifier()
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = rf.predict(x_test)

# %%
acc_score = accuracy_score(y_pred,y_test)

# %%
acc_score
# Out:
# 0.20077220077220076

# %%
classification = classification_report(y_pred,y_test)
print(classification)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.23      0.24      0.23        88
#            1       0.23      0.28      0.26        74
#            2       0.13      0.10      0.12        97
#
#     accuracy                           0.20       259
#    macro avg       0.20      0.21      0.20       259
# weighted avg       0.19      0.20      0.20       259
